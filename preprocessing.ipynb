# %% [markdown]
# <a href="https://colab.research.google.com/github/sujeet311/Quantuma_Boosting/blob/main/preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/FINALCODE/Data/db_data.csv') #Load the CSV file
df.shape
# Out:
# (253680, 22)

# %%
df['Diabetes_binary'].value_counts()
# Out:
# 0.0    218334
# 1.0     35346
# Name: Diabetes_binary, dtype: int64

# %%
df.sample(5)
# Out:
#         Diabetes_binary  HighBP  HighChol  CholCheck   BMI  Smoker  Stroke  \
# 95759               0.0     1.0       0.0        1.0  23.0     1.0     0.0
# 232975              0.0     0.0       1.0        1.0  29.0     1.0     1.0
# 182052              0.0     0.0       0.0        1.0  27.0     0.0     0.0
# 194233              0.0     1.0       0.0        1.0  33.0     0.0     0.0
# 62056               0.0     0.0       0.0        0.0  20.0     1.0     0.0
#
#         HeartDiseaseorAttack  PhysActivity  Fruits  ...  AnyHealthcare  \
# 95759                    0.0           1.0     1.0  ...            1.0
# 232975                   0.0           1.0     1.0  ...            1.0
# 182052                   0.0           1.0     1.0  ...            1.0
# 194233                   0.0           0.0     0.0  ...            1.0
# 62056                    0.0           1.0     1.0  ...            1.0
#
#         NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex   Age  \
# ...

# %%
df.describe()
# Out:
#        Diabetes_binary         HighBP       HighChol      CholCheck  \
# count    253680.000000  253680.000000  253680.000000  253680.000000
# mean          0.139333       0.429001       0.424121       0.962670
# std           0.346294       0.494934       0.494210       0.189571
# min           0.000000       0.000000       0.000000       0.000000
# 25%           0.000000       0.000000       0.000000       1.000000
# 50%           0.000000       0.000000       0.000000       1.000000
# 75%           0.000000       1.000000       1.000000       1.000000
# max           1.000000       1.000000       1.000000       1.000000
#
#                  BMI         Smoker         Stroke  HeartDiseaseorAttack  \
# count  253680.000000  253680.000000  253680.000000         253680.000000
# mean       28.382364       0.443169       0.040571              0.094186
# std         6.608694       0.496761       0.197294              0.292087
# ...

# %% [markdown]
# # Check for Null value in dataset
#
# ---

# %%
#visualizing the null values

msno.bar(df)

# %% [markdown]
# Distribution of datset class

# %%
#pie chart
labels = ['Non-Dibetic','Diabetic']
ex=[0.1,0]

plt.figure(figsize = (5,5))
df.Diabetes_binary.value_counts().plot.pie(labels=labels, autopct='%0.2f%%',shadow=True,explode=ex)

# %% [markdown]
# # Checking for Duplicates value
#
# ---

# %%
# Checking duplicates
duplicates = df[df.duplicated()]
print("Duplicate Rows : ",len(duplicates))
# Out:
# Duplicate Rows :  24206

# %%
# Removing duplicate rows from the dataset
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (229474, 22)

# %% [markdown]
# # Pie chart after removing the duplicates value
#
# ---

# %%
#pie chart
labels = 'Healthy','Diabetic'
ex=[0.1,0]
plt.figure(figsize = (5,5))
df.Diabetes_binary.value_counts().plot.pie(labels=labels, autopct='%0.2f%%',shadow=True,explode=ex)

# %% [markdown]
# ## EDA
#
# ---

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in df:
    if plotnumber <= 22:
        ax = plt.subplot(5, 5, plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column)

    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Diabetes_binary', 'HighBP', 'HighChol', 'CholCheck', 'BMI', 'Smoker',
#        'Stroke', 'HeartDiseaseorAttack', 'PhysActivity', 'Fruits', 'Veggies',
#        'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'GenHlth',
#        'MentHlth', 'PhysHlth', 'DiffWalk', 'Sex', 'Age', 'Education',
#        'Income'],
#       dtype='object')

# %%
# pair plot of sample feature
sns.pairplot(df, hue = 'Diabetes_binary',
             vars = ['HighBP', 'HighChol', 'CholCheck', 'BMI', 'Smoker'] )

# %%
# Histogram

df.hist(figsize=(30,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa587a8fbd0>,
# ...
#       dtype=object)

# %%
categorical_cols = ['HighBP','HighChol','CholCheck','Smoker','Stroke','HeartDiseaseorAttack',
'PhysActivity','Fruits', 'Veggies','HvyAlcoholConsump','AnyHealthcare','NoDocbcCost','GenHlth',
'DiffWalk','Sex','Education','Income']
numerical_cols=['BMI','MentHlth', 'PhysHlth']

# %%
plt.figure(figsize = (15,15))
for i,col in enumerate(['BMI', 'GenHlth', 'MentHlth', 'PhysHlth', 'Age','Education', 'Income']):
    plt.subplot(4,2,i+1)
    sns.boxplot(x = col, data = df)
plt.show()

# %%
def count_outliers(data,col):

    q1 = data[col].quantile(0.25,interpolation='nearest')
    q2 = data[col].quantile(0.5,interpolation='nearest')
    q3 = data[col].quantile(0.75,interpolation='nearest')
    q4 = data[col].quantile(1,interpolation='nearest')

    IQR = q3 -q1
    Lower_Bound = q1 - 1.5*IQR
    Upper_Bound = q3 + 1.5*IQR

    if data[col].min() > Lower_Bound and data[col].max() < Upper_Bound:
        print("No outliers in",i)
    else:
        print("There are outliers in",i)
        x = data[data[col]<Lower_Bound][col].size
        y = data[data[col]>Upper_Bound][col].size
        a.append(i)
        print('Count of outliers are:',x+y)

a = []
for i in numerical_cols:
    count_outliers(df,i)
# Out:
# There are outliers in BMI
# Count of outliers are: 5638
# There are outliers in MentHlth
# Count of outliers are: 36162
# There are outliers in PhysHlth
# Count of outliers are: 34346

# %%
df.to_csv('/content/drive/MyDrive/FINALCODE/Data/process_d.csv')
